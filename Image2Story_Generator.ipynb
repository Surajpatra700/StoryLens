# %% [markdown]
# <a href="https://colab.research.google.com/github/Surajpatra700/StoryLens/blob/main/Image2Story_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
TOKEN_KEY = "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"

# %%
from transformers import pipeline
# def img2text(url ="https://d38b044pevnwc9.cloudfront.net/cutout-nuxt/enhancer/2.jpg"):
#   image_to_text = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base ")
#   text = image_to_text(url)[0]['generated_text']
#   print(text)
#   return text

# %%
# !pip install transformers torch pillow

import requests
from PIL import Image
from transformers import pipeline

TOKEN_KEY = "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"

# Set up the Hugging Face pipeline
image_to_text = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base",
                          token=TOKEN_KEY)  # Make sure to pass the token

def img2text(url):
    # Download the image
    response = requests.get(url)
    img = Image.open(requests.get(url, stream=True).raw)

    # Generate text from the image
    text = image_to_text(img)[0]['generated_text']
    print(text)
    return text
# Out:
# ...
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
# !pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 26.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 30.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
# ...

# %%
from langchain import PromptTemplate, LLMChain
from langchain.llms.huggingface_hub import HuggingFaceHub

# def generate_story(scenario):
#     # Define the template for the prompt
#     template = """
#     You are a storyteller;
#     You can generate a beautiful short story based on a simple narrative, the story should be of word length of 80-100.

#     CONTEXT: {scenario}
#     STORY:
#     """


# def generate_story(scenario, genre):
#     # Define the template for the prompt
#     template = f"""
#     You are a storyteller with expertise in various genres. Your can generate an appropriate and a beautiful short paragraph story based on the given scenario {scenario} and genre {genre}. The story must be exactly between 200-300 words in a single paragraph.

#     CONTEXT: {scenario}
#     GENRE: {genre}

#     INSTRUCTIONS:
#     - It should fully capture the essence of the {genre} genre.
#     - Include vivid descriptions, engaging characters, and a clear narrative arc with a beginning, middle, and end.
#     - Ensure the story evokes emotions and immerses the reader.

#     STORY:
#     """

#     # Create a prompt template with a placeholder for 'scenario'
#     prompt = PromptTemplate(template=template, input_variables=["scenario"])

#     # Use the Hugging Face GPT-Neo 2.7B model
#     story_llm = HuggingFaceHub(
#         repo_id="EleutherAI/gpt-neo-2.7B",  # Model ID for GPT-Neo 2.7B
#         huggingfacehub_api_token="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",  # Replace with your API token
#         model_kwargs={
#             "temperature": 0.6,  # Adjust creativity
#             "top_p": 0.95,       # Nucleus sampling for diversity
#             "max_new_tokens": 240, # Set a limit for response length
#             "repetition_penalty": 2
#         }
#     )

#     # Create an LLMChain using the prompt and the Hugging Face model
#     story_chain = LLMChain(prompt=prompt, llm=story_llm, verbose=True)

#     # Generate the story based on the scenario
#     story = story_chain.predict(scenario=scenario)  # Pass 'scenario' as input
#     print(story)
#     return story

def generate_story(scenario, genre):
    # Define the template for the prompt
    template = f"""
    You are a storyteller with expertise in various genres. Your can generate an appropriate and a beautiful short paragraph complete story based on the given scenario {scenario} and genre {genre}. The story must be exactly between 200-300 words in a single complete paragraph.

    CONTEXT: {scenario}
    GENRE: {genre}

    INSTRUCTIONS:
    - It should fully capture the essence of the {genre} genre.
    - Include vivid descriptions, engaging characters, and a clear narrative arc with a beginning, middle, and end.
    - Ensure the story evokes emotions and immerses the reader.

    STORY:
    """

    prompt = PromptTemplate(template=template, input_variables=["scenario"])
    story_llm = HuggingFaceHub(
        repo_id="EleutherAI/gpt-neo-2.7B",
        huggingfacehub_api_token="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",
        model_kwargs={"temperature": 0.6, "top_p": 0.95, "max_new_tokens": 300, "repetition_penalty": 2}
    )

    story_chain = LLMChain(prompt=prompt, llm=story_llm, verbose=True)
    full_output = story_chain.predict(scenario=scenario)

    # Extracting the story by splitting based on "STORY:" marker
    if "STORY:" in full_output:
        story = full_output.split("STORY:")[1].strip()
    else:
        story = full_output.strip()  # Fallback to the full output if no split marker

    print(story)
    return story

# %%
import requests

# def txt2Speech(msg):
#     # API_URL = "https://api-inference.huggingface.co/models/facebook/wav2vec2-large-960h-lv60-self"
#     API_URL = "https://api-inference.huggingface.co/models/espnet/kan-bayashi_ljspeech_vits"
#     headers = {"Authorization": f"Bearer {TOKEN_KEY}"}
#     payloads = {
#         "inputs": msg
#     }

#     response = requests.post(API_URL, headers=headers, json=payloads)

#     # Check if the request was successful
#     if response.status_code == 200:
#         # Check content type, whether it's audio or another format
#         content_type = response.headers.get('Content-Type')

#         # If content type is audio
#         if "audio" in content_type:
#             with open('audio.wav', 'wb') as file:  # Saving it as .wav instead of .mp3
#                 file.write(response.content)
#             print("Audio saved successfully!")
#         else:
#             print("The response did not return audio content.")
#     else:
#         print(f"Failed to fetch audio: {response.status_code}")

TOKEN_KEY_2 = "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"
def txt2Speech(msg):
    API_URL = "https://api-inference.huggingface.co/models/espnet/kan-bayashi_ljspeech_vits"  # Correct TTS Model
    headers = {"Authorization": f"Bearer {TOKEN_KEY_2}"}
    payloads = {
        "inputs": msg
    }

    response = requests.post(API_URL, headers=headers, json=payloads)

    if response.status_code == 200:
        with open('audio.wav', 'wb') as file:
            file.write(response.content)
        print("Audio saved successfully!")
    else:
        print(f"Failed to fetch audio: {response.status_code}, {response.json().get('error', 'Unknown error')}")

# %%
# import requests

# TOKEN_KEY_2 = "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"

# def txt22Speech(msg):
#     API_URL = "https://api-inference.huggingface.co/models/speechbrain/tts-tacotron2-ljspeech"
#     headers = {"Authorization": f"Bearer {TOKEN_KEY_2}"}
#     payloads = {
#         "inputs": msg
#     }

#     response = requests.post(API_URL, headers=headers, json=payloads)

#     if response.status_code == 200:
#         content_type = response.headers.get('Content-Type')
#         if "audio" in content_type:
#             with open('audio.wav', 'wb') as file:
#                 file.write(response.content)
#             print("Audio saved successfully!")
#         else:
#             print("The response did not return audio content.")
#     else:
#         print(f"Failed to fetch audio: {response.status_code}, {response.json().get('error', 'Unknown error')}")

# %%
# !pip install gtts pydub
from gtts import gTTS
from pydub import AudioSegment

# Install dependencies if you haven't already:
# pip install gtts pydub

# Function to convert text to speech
def text_to_indian_accent_speech(text, output_file="output.wav"):
    # Generate TTS in Indian English
    tts = gTTS(text=text, lang='en', tld='co.in')  # tld='co.in' for Indian English accent

    # Save as mp3 (default format)
    temp_mp3 = "temp_output.mp3"
    tts.save(temp_mp3)

    # Convert mp3 to wav
    sound = AudioSegment.from_mp3(temp_mp3)
    sound.export(output_file, format="wav")

    print(f"Speech saved as {output_file}")

# Example usage
text = "Hello, this is a sample text converted to Indian English speech."
text_to_indian_accent_speech(text)
# Out:
# ...
# Speech saved as output.wav

# %%
# !pip install googletrans==4.0.0-rc1 gtts pydub
from googletrans import Translator
from gtts import gTTS
from pydub import AudioSegment

# Install dependencies if you haven't already:
def english_to_hindi_speech(text, output_file="output_hindi.wav"):
    # Translate English text to Hindi
    translator = Translator()
    translated_text = translator.translate(text, src='en', dest='hi').text
    print(f"Translated Text: {translated_text}")

    # Convert translated Hindi text to speech
    tts = gTTS(text=translated_text, lang='hi', tld='co.in')  # tld='co.in' for Indian Hindi accent

    # Save as mp3
    temp_mp3 = "temp_output_hindi.mp3"
    tts.save(temp_mp3)

    # Convert mp3 to wav
    sound = AudioSegment.from_mp3(temp_mp3)
    sound.export(output_file, format="wav")

    print(f"Hindi speech saved as {output_file}")

# Example usage
english_text = "I have just moved into my new house. It is a dark and gloomy place. There are no lights on in the house. The only light is coming from the street below. I am alone in the house. I don't know what to do. I don't know where to go. I don't know who to ask for help. I don't know how to get out of this house. I don't know what to do. I don't know what to do. I don't know where to go. I don't know who to ask for help. I don't know how to get out of this house. I don't know what to do. I don't know what to do. I don't know where to go. I don't know who to ask for help. I don't know how to get out of this house. I don't know what to do. I don't know what to do. I don't know where to go. I don't know who to ask for help. I don't know how to get out of this house. I don't know what to do. I don't know what to do. I don't know where to go. I don't know who to ask for help. I don't know how to get out of this house. I don't know what to do. I don't know what to do. I don't know where to go. I don't know who to ask for"
english_to_hindi_speech(english_text)
# Out:
# ...
# Translated Text: मैं सिर्फ अपने नए घर में चला गया हूं।यह एक अंधेरे और उदास जगह है।घर में कोई रोशनी नहीं है।नीचे सड़क से एकमात्र प्रकाश आ रहा है।मैं घर में अकेला हूँ।मुझे नहीं पता क्या करना है।मुझे नहीं पता कि कहाँ जाना है।मुझे नहीं पता कि किसे मदद मांगनी है।मुझे नहीं पता कि इस घर से बाहर कैसे निकलना है।मुझे नहीं पता क्या करना है।मुझे नहीं पता क्या करना है।मुझे नहीं पता कि कहाँ जाना है।मुझे नहीं पता कि किसे मदद मांगनी है।मुझे नहीं पता कि इस घर से बाहर कैसे निकलना है।मुझे नहीं पता क्या करना है।मुझे नहीं पता क्या करना है।मुझे नहीं पता कि कहाँ जाना है।मुझे नहीं पता कि किसे मदद मांगनी है।मुझे नहीं पता कि इस घर से बाहर कैसे निकलना है।मुझे नहीं पता क्या करना है।मुझे नहीं पता क्या करना है।मुझे नहीं पता कि कहाँ जाना है।मुझे नहीं पता कि किसे मदद मांगनी है।मुझे नहीं पता कि इस घर से बाहर कैसे निकलना है।मुझे नहीं पता क्या करना है।मुझे नहीं पता क्या करना है।मुझे नहीं पता कि कहाँ जाना है।मुझे नहीं पता कि किसे मदद मांगनी है।मुझे नहीं पता कि इस घर से बाहर कैसे निकलना है।मुझे नहीं पता क्या करना है।मुझ
# ...

# %%
scenario = img2text("https://t3.ftcdn.net/jpg/05/27/96/24/360_F_527962462_zBAIJXHDfHGdnwLrOs2qrJkETb9Kah4B.jpg")
story = generate_story(scenario, "horrific")
txt2Speech(story)
text_to_indian_accent_speech(story)
english_to_hindi_speech(story)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1375: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# > Entering new LLMChain chain...
# Prompt after formatting:
#
#     You are a storyteller with expertise in various genres. Your can generate an appropriate and a beautiful short paragraph story based on the given scenario a house in the woods with a dark sky and genre horrific. The story must be exactly between 200-300 words in a single paragraph.
#
#     CONTEXT: a house in the woods with a dark sky
#     GENRE: horrific
#
#     INSTRUCTIONS:
#     - It should fully capture the essence of the horrific genre.
# ...

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 61.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 83.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.6 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
from transformers import pipeline
from langchain import PromptTemplate, LLMChain
from langchain.llms.huggingface_hub import HuggingFaceHub

# Function to extract text from an image
def img2text(image):
    # Convert the uploaded file to bytes
    image_to_text = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base")
    text = image_to_text(image)[0]['generated_text']
    return text

# Function to generate a story based on a given scenario
def generate_story(scenario):
    template = """
    You are a creative & brilliant storyteller;
    You can generate an amazing and complete short story based on an awesome narrative, the story should fit and complete between 120 and 150 words.

    CONTEXT: {scenario}
    STORY:
    """

    prompt = PromptTemplate(template=template, input_variables=["scenario"])

    story_llm = HuggingFaceHub(
        repo_id="EleutherAI/gpt-neo-2.7B",
        huggingfacehub_api_token="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",
        model_kwargs={
            "temperature": 0.7,
            "top_p": 0.95,
            "max_new_tokens": 125
        }
    )

    story_chain = LLMChain(prompt=prompt, llm=story_llm, verbose=False)
    story = story_chain.predict(scenario=scenario)
    return story

# Streamlit interface
st.title("Image to Short Story Generator")
st.write("Upload an image and we'll generate a story based on it!")

# Upload image
uploaded_image = st.file_uploader("Choose an image...", type="jpg")

if uploaded_image is not None:
    st.image(uploaded_image, caption="Uploaded Image", use_column_width=True)

    # Generate text from image
    with st.spinner("Extracting text from image..."):
        img_text = img2text(uploaded_image)
        st.write(f"Extracted Text: {img_text}")

    # Generate story
    with st.spinner("Generating a story based on the image..."):
        story = generate_story(img_text)
        st.write("Generated Story:")
        st.write(story)
# Out:
# 2024-11-19 10:12:27.207 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-19 10:12:27.280
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2024-11-19 10:12:27.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-19 10:12:27.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-19 10:12:27.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-19 10:12:27.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-19 10:12:27.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# convert ipynb file to .py file
# !jupyter nbconvert --to script Untitled16.ipynb
# !streamlit run Untitled16.ipynb
# Out:
# [NbConvertApp] WARNING | pattern 'Untitled16.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
#     Equivalent to: [--JupyterApp.generate_config=True]
# ...

# %%
# !ls -l
# Out:
# total 8
# drwx------ 6 root root 4096 Nov 19 10:08 drive
# drwxr-xr-x 1 root root 4096 Nov 15 14:19 sample_data

# %%
# !jupyter nbconvert --to script /content/drive/MyDrive/Colab Notebooks/Untitled16.ipynb
# !streamlit run Untitled16.py
# Out:
# [NbConvertApp] WARNING | pattern '/content/drive/MyDrive/Colab' matched no files
# [NbConvertApp] WARNING | pattern 'Notebooks/Untitled16.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
# ...

# %% [markdown]
# !pip install gradio transformers torch pillow requests langchain

# %%
import gradio as gr
import requests
from PIL import Image
from transformers import pipeline
from langchain import PromptTemplate, LLMChain
from langchain.llms.huggingface_hub import HuggingFaceHub

# Tokens
IMAGE_CAPTION_TOKEN = "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"
STORY_GEN_TOKEN = "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"
TTS_TOKEN = "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"

# Image Captioning Pipeline
image_to_text = pipeline(
    "image-to-text",
    model="Salesforce/blip-image-captioning-base",
    token="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"
)

# Story Generation using GPT-Neo
def generate_story(scenario, genre):
    template = f"""
    You are a storyteller. Generate a {genre} short paragraph story based on the given context:

    CONTEXT: {scenario}
    GENRE: {genre}

    STORY:
    """
    prompt = PromptTemplate(template=template, input_variables=["scenario"])
    story_llm = HuggingFaceHub(
        repo_id="EleutherAI/gpt-neo-2.7B",
        huggingfacehub_api_token="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",
        model_kwargs={"temperature": 0.7, "top_p": 0.9, "max_new_tokens": 300}
    )
    story_chain = LLMChain(prompt=prompt, llm=story_llm)
    return story_chain.predict(scenario=scenario)

# TTS using ESPnet VITS
def txt2Speech(msg):
    API_URL = "https://api-inference.huggingface.co/models/espnet/kan-bayashi_ljspeech_vits"
    headers = {"Authorization": f"Bearer {TTS_TOKEN}"}
    payloads = {"inputs": msg}
    response = requests.post(API_URL, headers=headers, json=payloads)
    if response.status_code == 200:
        return response.content
    else:
        return f"Error: {response.status_code}"

# Combined function
# def process_image(image, genre):
#     scenario = image_to_text(image)[0]['generated_text']
#     story = generate_story(scenario, genre)
#     audio = txt2Speech(story)
#     return story, (audio, "audio/wav")

def process_image(image, genre):
    scenario = image_to_text(image)[0]['generated_text']
    story = generate_story(scenario, genre)
    audio_data = txt2Speech(story)

    # Save audio file
    audio_path = "narrated_story.wav"
    with open(audio_path, "wb") as audio_file:
        audio_file.write(audio_data)

    return story, audio_path

# Gradio Interface
genres = ["horror", "narrative", "general", "adventurous", "suspense", "romantic", "historic"]

with gr.Blocks() as demo:
    gr.Markdown("## Image to Story Generator and Narration")
    with gr.Row():
        image = gr.Image(type="pil")
        genre = gr.Dropdown(choices=genres, label="Select Genre")
    generate_btn = gr.Button("Generate Story")
    story_output = gr.Textbox(label="Generated Story", lines=10)
    audio_output = gr.Audio(label="Narrated Story", type="file")

    generate_btn.click(process_image, [image, genre], [story_output, audio_output])

demo.launch(share=True)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-3bd8e163ae1d> in <cell line: 72>()
#      77     generate_btn = gr.Button("Generate Story")
#      78     story_output = gr.Textbox(label="Generated Story", lines=10)
# ---> 79     audio_output = gr.Audio(label="Narrated Story", type="file")
#      80
#      81     generate_btn.click(process_image, [image, genre], [story_output, audio_output])
#
# /usr/local/lib/python3.10/dist-packages/gradio/component_meta.py in wrapper(*args, **kwargs)
#     177             return None
#     178         else:
# --> 179             return fn(self, **kwargs)
#     180
#     181     return wrapper
#
# ...

# %%
# ************************************** STREAMLIT DEPLOYMENT ************************************

# %%
# !pip install streamlit pyngrok
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 38.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 61.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.7 MB/s eta 0:00:00
# ...

# %%
from pyngrok import ngrok
# !streamlit run app.py &>/dev/null&
public_url = ngrok.connect(port=8501)
print(public_url)
# Out:
# WARNING:pyngrok.process.ngrok:t=2024-11-19T18:57:11+0000 lvl=warn msg="invalid tunnel configuration" pg=/api/tunnels id=f5aa796b53b029b0 err="yaml: unmarshal errors:\n  line 1: field port not found in type config.HTTPv2Tunnel"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     521     try:
# --> 522         response = urlopen(request, encoded_data, timeout)
#     523         response_data = response.read().decode("utf-8")
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
# ...

# %%
# !pip install transformers torch pillow
# !pip install langchain-community
# !pip install gtts pydub
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 29.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 40.3 MB/s eta 0:00:00
# ...

# %%
# %%writefile app.py
import streamlit as st
# from PIL import Image
# import reqimport streamlit as st
from PIL import Image
import requests
from gtts import gTTS
from pydub import AudioSegment
from googletrans import Translator
import base64



# Your image captioning and story generation functions
# from your_functions import img2text, generate_story, text_to_speech, text_to_speech_hindi

# ************** Image2Text model ***********************

# import requests
# from PIL import Image
from transformers import pipeline

TOKEN_KEY = "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"

# Set up the Hugging Face pipeline
image_to_text = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base",
                          token=TOKEN_KEY)  # Make sure to pass the token

# def img2text(url):
#     # Download the image
#     response = requests.get(url)
#     img = Image.open(requests.get(url, stream=True).raw)

#     # Generate text from the image
#     text = image_to_text(img)[0]['generated_text']
#     print(text)
#     return text

def img2text(input_image):
    if isinstance(input_image, str):  # If input is a URL
        response = requests.get(input_image)
        img = Image.open(requests.get(input_image, stream=True).raw)
    elif isinstance(input_image, Image.Image):  # If input is a PIL Image object
        img = input_image
    else:
        raise ValueError("Invalid input type. Provide a URL or PIL Image.")

    # Generate text from the image
    text = image_to_text(img)[0]['generated_text']
    return text




# ************** Generate Story Model *******************

from langchain import PromptTemplate, LLMChain
from langchain.llms.huggingface_hub import HuggingFaceHub

def generate_story(scenario, genre):
    # Define the template for the prompt
    template = f"""
    You are a storyteller with expertise in various genres. Your can generate an appropriate and a beautiful short paragraph story based on the given scenario {scenario} and genre {genre}. The story must be exactly between 200-300 words in a single complete paragraph.

    CONTEXT: {scenario}
    GENRE: {genre}

    INSTRUCTIONS:
    - It should fully capture the essence of the {genre} genre.
    - Include vivid descriptions, engaging characters, and a clear narrative arc with a beginning, middle, and end.
    - Ensure the story evokes emotions and immerses the reader.

    STORY:
    """

    prompt = PromptTemplate(template=template, input_variables=["scenario"])
    story_llm = HuggingFaceHub(
        repo_id="EleutherAI/gpt-neo-2.7B",
        huggingfacehub_api_token="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",
        model_kwargs={"temperature": 0.6, "top_p": 0.95, "max_new_tokens": 500, "repetition_penalty": 2}
    )

    story_chain = LLMChain(prompt=prompt, llm=story_llm, verbose=True)
    full_output = story_chain.predict(scenario=scenario)

    # Extracting the story by splitting based on "STORY:" marker
    if "STORY:" in full_output:
        story = full_output.split("STORY:")[1].strip()
    else:
        story = full_output.strip()  # Fallback to the full output if no split marker


    # print(story)
    return story

# ************** Text to Speech English Model *************



# ************************* COMMENTING FROM HERE **********************************


# English Text-to-Speech
def text_to_indian_accent_speech(text, output_file="output.wav"):
    tts = gTTS(text=text, lang='en', tld='co.in')
    temp_mp3 = "temp_output.mp3"
    tts.save(temp_mp3)
    sound = AudioSegment.from_mp3(temp_mp3)
    sound.export(output_file, format="wav")
    return output_file

# Hindi Text-to-Speech
def english_to_hindi_speech(text, output_file="output_hindi.wav"):
    translator = Translator()
    translated_text = translator.translate(text, src='en', dest='hi').text
    tts = gTTS(text=translated_text, lang='hi', tld='co.in')
    temp_mp3 = "temp_output_hindi.mp3"
    tts.save(temp_mp3)
    sound = AudioSegment.from_mp3(temp_mp3)
    sound.export(output_file, format="wav")
    return output_file

# Function to generate download link
def download_link(file_path, filename):
    with open(file_path, "rb") as f:
        audio_data = f.read()
    audio_base64 = base64.b64encode(audio_data).decode()
    return f'<a href="data:audio/wav;base64,{audio_base64}" download="{filename}">Download {filename}</a>'

# Streamlit UI
st.title("StoryLens: AI Story Teller")

uploaded_file = st.file_uploader("Choose an image...", type=["jpg", "png", "jpeg"])
image_url = st.text_input("Or paste an image URL")
genre = st.selectbox("Select a story genre:", ["Adventurous", "Horrific", "Narrative", "Historic", "Romantic", "Comedy"])

# Generate Story
if st.button("Generate Story"):
    if uploaded_file or image_url:
        image = Image.open(uploaded_file) if uploaded_file else Image.open(requests.get(image_url, stream=True).raw)
        st.image(image, caption="Uploaded Image")

        scenario = img2text(image)
        story = generate_story(scenario, genre)
        st.session_state["story"] = story  # Store the story in session state

        st.write("### Generated Story")
        st.write(story)
        st.markdown('<span style="color:blue;">Read more...</span>', unsafe_allow_html=True)

    else:
        st.warning("Please upload an image or provide an image URL.")

# Check if story exists in session state
if "story" in st.session_state:
    story = st.session_state["story"]

    if st.button("Convert Story to English Speech"):
        english_audio = text_to_indian_accent_speech(story)
        st.audio(english_audio, format="audio/wav")
        st.markdown(download_link(english_audio, "english_speech.wav"), unsafe_allow_html=True)

    if st.button("Convert Story to Hindi Speech"):
        hindi_audio = english_to_hindi_speech(story)
        st.audio(hindi_audio, format="audio/wav")
        st.markdown(download_link(hindi_audio, "hindi_speech.wav"), unsafe_allow_html=True)
else:
    st.info("Generate a story first to convert it to speech.")


# from gtts import gTTS
# from pydub import AudioSegment

# # Install dependencies if you haven't already:
# pip install gtts pydub

# # Function to convert text to speech
# # def text_to_indian_accent_speech(text, output_file="output.wav"):
# #     # Generate TTS in Indian English
# #     tts = gTTS(text=text, lang='en', tld='co.in')  # tld='co.in' for Indian English accent

# #     # Save as mp3 (default format)
# #     temp_mp3 = "temp_output.mp3"
# #     tts.save(temp_mp3)

# #     # Convert mp3 to wav
# #     sound = AudioSegment.from_mp3(temp_mp3)
# #     sound.export(output_file, format="wav")

# #     print(f"Speech saved as {output_file}")

# def text_to_indian_accent_speech(text, output_file="output.wav"):
#     from gtts import gTTS
#     from pydub import AudioSegment

#     tts = gTTS(text=text, lang='en', tld='co.in')
#     temp_mp3 = "temp_output.mp3"
#     tts.save(temp_mp3)

#     sound = AudioSegment.from_mp3(temp_mp3)
#     sound.export(output_file, format="wav")

#     print(f"Audio file saved at {output_file}")  # Debugging line

#     return output_file  # Return the path to the generated audio file




# # ************** Text to Speech Hindi Model *************


# from googletrans import Translator
# from gtts import gTTS
# from pydub import AudioSegment

# # Install dependencies if you haven't already:
# # def english_to_hindi_speech(text, output_file="output_hindi.wav"):
# #     # Translate English text to Hindi
# #     translator = Translator()
# #     translated_text = translator.translate(text, src='en', dest='hi').text
# #     print(f"Translated Text: {translated_text}")

# #     # Convert translated Hindi text to speech
# #     tts = gTTS(text=translated_text, lang='hi', tld='co.in')  # tld='co.in' for Indian Hindi accent

# #     # Save as mp3
# #     temp_mp3 = "temp_output_hindi.mp3"
# #     tts.save(temp_mp3)

# #     # Convert mp3 to wav
# #     sound = AudioSegment.from_mp3(temp_mp3)
# #     sound.export(output_file, format="wav")

# #     print(f"Hindi speech saved as {output_file}")

# def english_to_hindi_speech(text, output_file="output_hindi.wav"):
#     from googletrans import Translator
#     from gtts import gTTS
#     from pydub import AudioSegment

#     translator = Translator()
#     translated_text = translator.translate(text, src='en', dest='hi').text

#     tts = gTTS(text=translated_text, lang='hi', tld='co.in')
#     temp_mp3 = "temp_output_hindi.mp3"
#     tts.save(temp_mp3)

#     sound = AudioSegment.from_mp3(temp_mp3)
#     sound.export(output_file, format="wav")

#     print(f"Audio file saved at {output_file}")  # Debugging line

#     return output_file  # Return the path to the generated audio file



# # Web App Structure
# st.title("Image-to-Story Generation")

# # Upload Image
# uploaded_file = st.file_uploader("Choose an image...", type=["jpg", "png", "jpeg"])
# image_url = st.text_input("Or paste an image URL")

# # Select Genre
# genre = st.selectbox("Select a story genre:", ["Adventurous", "Horrific", "Narrative", "Historic", "Romantic", ""])

# # Generate Story
# if st.button("Generate Story"):
#     if uploaded_file or image_url:
#         # Load the image
#         image = Image.open(uploaded_file) if uploaded_file else Image.open(requests.get(image_url, stream=True).raw)
#         st.image(image, caption="Uploaded Image")

#         # Generate caption and story
#         scenario = img2text(image)  # Use the function to generate a caption
#         story = generate_story(scenario, genre)  # Generate story based on caption and genre

#         st.write("### Generated Story")
#         st.write(story)

#         # # Text-to-Speech Buttons
#         # if st.button("Convert Story to English Speech"):
#         #     english_audio = text_to_indian_accent_speech(story)  # Correct function for Indian-accent speech
#         #     st.audio(english_audio)

#         # if st.button("Convert Story to Hindi Speech"):
#         #     hindi_audio = english_to_hindi_speech(story)  # Correct function for Hindi speech
#         #     st.audio(hindi_audio)

#         import base64

#         def download_link(file_path, filename):
#             with open(file_path, "rb") as f:
#                 audio_data = f.read()
#             audio_base64 = base64.b64encode(audio_data).decode()
#             return f'<a href="data:audio/wav;base64,{audio_base64}" download="{filename}">Download {filename}</a>'

#         # Text-to-Speech Buttons
#         if st.button("Convert Story to English Speech"):
#             english_audio = text_to_indian_accent_speech(story)
#             if english_audio:
#                 st.audio(english_audio, format="audio/wav")
#                 st.markdown(download_link(english_audio, "english_speech.wav"), unsafe_allow_html=True)
#             else:
#                 st.error("Error generating English speech.")

#         if st.button("Convert Story to Hindi Speech"):
#             hindi_audio = english_to_hindi_speech(story)
#             if hindi_audio:
#                 st.audio(hindi_audio, format="audio/wav")
#                 st.markdown(download_link(hindi_audio, "hindi_speech.wav"), unsafe_allow_html=True)
#             else:
#                 st.error("Error generating Hindi speech.")


#     else:
#         st.warning("Please upload an image or provide an image URL.")
# Out:
# Overwriting app.py

# %%
# !ngrok config add-authtoken 2p4ykNgVwF6sh9AQa2TClFmZQpm_4WfqXsSEUw7EoBp89cjXv
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import ngrok

# Start Streamlit in the background
import os
os.system("streamlit run app.py --server.port 8501 &")

# Start ngrok tunnel
public_url = ngrok.connect(8501)
print("Streamlit App URL:", public_url)
# Out:
# Streamlit App URL: NgrokTunnel: "https://0a51-34-19-27-73.ngrok-free.app" -> "http://localhost:8501"

# %%
from gtts import gTTS
from pydub import AudioSegment

# Install dependencies if you haven't already:
# pip install gtts pydub

# Function to convert text to speech
# def text_to_indian_accent_speech(text, output_file="output.wav"):
#     # Generate TTS in Indian English
#     tts = gTTS(text=text, lang='en', tld='co.in')  # tld='co.in' for Indian English accent

#     # Save as mp3 (default format)
#     temp_mp3 = "temp_output.mp3"
#     tts.save(temp_mp3)

#     # Convert mp3 to wav
#     sound = AudioSegment.from_mp3(temp_mp3)
#     sound.export(output_file, format="wav")

#     print(f"Speech saved as {output_file}")

def text_to_indian_accent_speech(text, output_file="output.wav"):
    from gtts import gTTS
    from pydub import AudioSegment

    tts = gTTS(text=text, lang='en', tld='co.in')
    temp_mp3 = "temp_output.mp3"
    tts.save(temp_mp3)

    sound = AudioSegment.from_mp3(temp_mp3)
    sound.export(output_file, format="wav")

    print(f"Audio file saved at {output_file}")  # Debugging line

    return output_file  # Return the path to the generated audio file

text_to_indian_accent_speech("People walking on the platform of a train station There was a man who was tired from his day's work. He had just walked for about three hours to get home when he heard a commotion coming from the next stop. He looked around but could see no one. He decided to go there and check it out. When he got there, he saw that someone had gotten off the train and was standing at the door. He thought it was strange because he couldn't see anyone. He went over to the person and asked him what was going on. The man told him that he had been waiting for quite some time now and finally decided to come inside. The man then invited him to have a seat. After a while, the man started telling him all about his day. As they talked, the man realized that he didn't have anything to eat so he asked the man if he could buy him something. The man agreed and gave him some money. They then went back to their seats. About five minutes later, the man noticed that the man hadn't moved. He then asked him if everything was okay. The man said yes and continued talking to him. Then, the man became aware that the man was staring at him. He felt very uncomfortable and wondered why he was being stared at. He then realized that the man was staring at him as if he was a ghost. The man then asked him if he wanted to go for")
# Out:
# Audio file saved at output.wav
# 'output.wav'

# %%
# ************** Image2Text model ***********************

# !pip install transformers torch pillow

import requests
from PIL import Image
from transformers import pipeline

TOKEN_KEY = "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"

# Set up the Hugging Face pipeline
image_to_text = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base",
                          token=TOKEN_KEY)  # Make sure to pass the token

def img2text(url):
    # Download the image
    response = requests.get(url)
    img = Image.open(requests.get(url, stream=True).raw)

    # Generate text from the image
    text = image_to_text(img)[0]['generated_text']
    print(text)
    return text


# !pip install langchain-community
# Out:
# ...
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 356.7 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 369.5 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 662.4 kB/s eta 0:00:00
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
# ...

# %%
# ************** Text to Speech Hindi Model *************

# !pip install googletrans==4.0.0-rc1 gtts pydub
from googletrans import Translator
from gtts import gTTS
from pydub import AudioSegment

# Install dependencies if you haven't already:
def english_to_hindi_speech(text, output_file="output_hindi.wav"):
    # Translate English text to Hindi
    translator = Translator()
    translated_text = translator.translate(text, src='en', dest='hi').text
    print(f"Translated Text: {translated_text}")

    # Convert translated Hindi text to speech
    tts = gTTS(text=translated_text, lang='hi', tld='co.in')  # tld='co.in' for Indian Hindi accent

    # Save as mp3
    temp_mp3 = "temp_output_hindi.mp3"
    tts.save(temp_mp3)

    # Convert mp3 to wav
    sound = AudioSegment.from_mp3(temp_mp3)
    sound.export(output_file, format="wav")

    print(f"Hindi speech saved as {output_file}")


# Web App Structure
st.title("Image-to-Story Generation")

# Upload Image
uploaded_file = st.file_uploader("Choose an image...", type=["jpg", "png", "jpeg"])
image_url = st.text_input("Or paste an image URL")

# Select Genre
genre = st.selectbox("Select a story genre:", ["Adventurous", "Horrific", "Narrative"])

# Generate Story
if st.button("Generate Story"):
    if uploaded_file or image_url:
        # Load the image
        image = Image.open(uploaded_file) if uploaded_file else Image.open(requests.get(image_url, stream=True).raw)
        st.image(image, caption="Uploaded Image")

        # Generate caption and story
        scenario = img2text(image)  # Use the function to generate a caption
        story = generate_story(scenario, genre)  # Generate story based on caption and genre

        st.write("### Generated Story")
        st.write(story)

        # Text-to-Speech Buttons
        if st.button("Convert Story to English Speech"):
            english_audio = text_to_indian_accent_speech(story)  # Correct function for Indian-accent speech
            st.audio(english_audio)

        if st.button("Convert Story to Hindi Speech"):
            hindi_audio = english_to_hindi_speech(story)  # Correct function for Hindi speech
            st.audio(hindi_audio)
    else:
        st.warning("Please upload an image or provide an image URL.")
